# %%
import glob
import pickle as pkl
import matplotlib.pyplot as plt
files = glob.glob("../dataset_centres/*.pkl")
files
# Out:
# ['../dataset_centres/spiral119154.pkl',
#  '../dataset_centres/spiral037026.pkl',
#  '../dataset_centres/spiral022046.pkl',
#  '../dataset_centres/spiral289131.pkl',
#  '../dataset_centres/spiral112153.pkl',
#  '../dataset_centres/spiral084172.pkl',
#  '../dataset_centres/spiral078122.pkl',
#  '../dataset_centres/spiral012044.pkl',
#  '../dataset_centres/spiral191141.pkl',
#  '../dataset_centres/spiral052231.pkl',
#  '../dataset_centres/spiral038165.pkl',
#  '../dataset_centres/spiral201123.pkl',
#  '../dataset_centres/spiral262115.pkl',
#  '../dataset_centres/spiral112227.pkl',
#  '../dataset_centres/spiral138041.pkl',
#  '../dataset_centres/multi4311.pkl',
#  '../dataset_centres/spiral179224.pkl',
#  '../dataset_centres/spiral111191.pkl',
#  '../dataset_centres/spiral280191.pkl',
#  '../dataset_centres/spiral248031.pkl',
#  '../dataset_centres/spiral182007.pkl',
#  '../dataset_centres/spiral315097.pkl',
#  '../dataset_centres/slow6590.pkl',
# ...

# %%
with open(files[0],"rb") as f:
    data = pkl.load(f,encoding='latin1') #encoding changed in Python3! here we read old files
data.keys()
# Out:
# dict_keys(['out', 'in'])

# %%
(data['out'].shape,data['in'].shape)
# Out:
# ((86, 86), (5, 86, 86))

# %%
plt.imshow(data["out"])

# %%
plt.imshow(data["in"][0])
